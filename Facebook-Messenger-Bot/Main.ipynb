# %%
import pandas as pd
import numpy as np
import os
import re
from datetime import datetime

# %%
# %run createDataset.py

# %%
# %run -i createDataset
# Out:
# Getting Google Hangout Data
# Getting Facebook Data
# Getting LinkedIn Data
# Total len of dictionary 6105
# Saving conversation data dictionary

# %%
# %run -i Word2Vec
# Out:
# Finished loading training matrices
# Finished loading word list
# Current loss is: 231.551
# Current loss is: 7.15702
# Current loss is: 3.65323
# Current loss is: 4.7566
# Current loss is: 3.24621
# Current loss is: 2.03238
# Current loss is: 3.30889
# Current loss is: 3.06907
# Current loss is: 2.91504
# Current loss is: 3.71495
# Saving the word embedding matrix

# %%
# %run -i Seq2Seq
# Out:
# Finished loading training matrices
# Current loss: 9.56719 at iteration 0
# hey how are you
# []
# Current loss: 9.08866 at iteration 50
# books
# []
# wssp
# []
# Current loss: 7.29872 at iteration 100
# whats up bro
# []
# hey how are you
# []
# Current loss: 6.06313 at iteration 150
# hi
# []
# hey how are you
# []
# Current loss: 4.1431 at iteration 200
# books
# []
# books
# []
# Current loss: 3.5889 at iteration 250
# wssp
# []
# hi
# []
# Current loss: 2.40346 at iteration 300
# wssp
# []
# books
# []
# Current loss: 1.81421 at iteration 350
# wssp
# []
# hey how are you
# []
# Current loss: 3.02088 at iteration 400
# wssp
# []
# whats up bro
# []
# Current loss: 1.64377 at iteration 450
# hey how are you
# []
# whats up bro
# []
# Current loss: 2.26165 at iteration 500
# hey how are you
# []
# books
# []
# Current loss: 2.31905 at iteration 550
# wssp
# []
# whats up bro
# []
# Current loss: 1.10072 at iteration 600
# wssp
# []
# wssp
# []
# ...
